# %%
from huggingface_hub import list_datasets

hits = list_datasets(search="math")        # server-side search, so it’s fast
for d in hits:
    print(d.id)
# Out:
# open-r1/OpenR1-Math-220k
# FractalAIResearch/Fathom-R1-14B_JEE-ADV-2025-math-responses
# AI4Math/MathVerse
# xinlai/Math-Step-DPO-10K
# nlile/hendrycks-MATH-benchmark
# allenai/math_qa
# dali-does/clevr-math
# qwedsacf/grade-school-math-instructions
# ChristophSchuhmann/basic-math-problems-with-step-by-step-solutions
# Mathoctopus/MGSM8KInstruct_Cross
# argilla/distilabel-math-preference-dpo
# MathLLMs/MathVision
# hkust-nlp/dart-math-pool-math
# hkust-nlp/dart-math-pool-gsm8k
# hkust-nlp/dart-math-uniform
# Zhiqiang007/MathV360K
# oz1115/openai_grade-school-math
# BAAI/IndustryCorpus_mathematics
# MaziyarPanahi/orca-math-word-problems-200k-sharegpt
# HuggingFaceH4/MATH-500
# andito/mathwriting-google
# URSA-MATH/URSA_Alignment_860K
# DigitalLearningGmbH/MATH-lighteval
# PrimeIntellect/verifiable-math-problems
# SynthLabsAI/Big-Math-RL-Verified
# BytedTsinghua-SIA/DAPO-Math-17k
# Intelligent-Internet/II-Thought-RL-v0-Math-50K
# a-m-team/AM-Math-Difficulty-RL
# BanglaLLM/bangla_math_by_Ashrafur
# MathArena/hmmt_feb_2025_outputs
# MathArena/usamo_2025
# miscovery/Math_CoT_Arabic_English_Reasoning
# lime-nlp/Synthetic_Unanswerable_Math
# MathArena/aime_2025_outputs
# MrLight/general-reasoner-verifier-analysis-math-verify
# MathLLMs/MM-MathInstruct
# THU-KEG/MM-Math-Align
# Shalyt/ASyMOB-Algebraic_Symbolic_Mathematical_Operations_Benchmark
# BreynaldDva/ARPO-MATH
# hendrycks/competition_math
# deepmind/math_dataset
# flax-sentence-embeddings/stackexchange_math_jsonl
# jakemarcus/MATH
# Azu/Handwritten-Mathematical-Expression-Convert-LaTeX
# mathigatti/spanish_imdb_synopsis
# SivilTaram/poet-math
# mathemakitten/winobias_antistereotype_dev
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-169e67-1524755111
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-f407ed-1527355152
# mathemakitten/glue-suite
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-08a58b-1563555688
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-7776e8-1573055858
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-e92f99-1572955856
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-7776e8-1573055859
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-e92f99-1572955857
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-7776e8-1573055860
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-e92f99-1572955855
# mathemakitten/winobias_antistereotype_test
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c50da3-1597456336
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c50da3-1597456333
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c50da3-1597456332
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c50da3-1597456329
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c50da3-1597456331
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c50da3-1597456330
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c50da3-1597456335
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c50da3-1597456334
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c793f9-1654758678
# autoevaluate/autoeval-eval-jeffdshen__redefine_math_test0-jeffdshen__redefine_math-58f952-1666158899
# autoevaluate/autoeval-eval-jeffdshen__redefine_math_test0-jeffdshen__redefine_math-58f952-1666158897
# autoevaluate/autoeval-eval-jeffdshen__redefine_math_test0-jeffdshen__redefine_math-58f952-1666158898
# autoevaluate/autoeval-eval-jeffdshen__redefine_math_test0-jeffdshen__redefine_math-58f952-1666158900
# autoevaluate/autoeval-eval-jeffdshen__redefine_math_test0-jeffdshen__redefine_math-58f952-1666158903
# autoevaluate/autoeval-eval-jeffdshen__redefine_math_test0-jeffdshen__redefine_math-58f952-1666158901
# autoevaluate/autoeval-eval-jeffdshen__redefine_math_test0-jeffdshen__redefine_math-58f952-1666158902
# autoevaluate/autoeval-eval-jeffdshen__redefine_math_test0-jeffdshen__redefine_math-58f952-1666158904
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-596cbd-1668659066
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-596cbd-1668659065
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-596cbd-1668659071
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-596cbd-1668659067
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-596cbd-1668659069
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-596cbd-1668659068
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-596cbd-1668659070
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-596cbd-1668659072
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-63d0bd-1672359217
# inverse-scaling/redefine-math
# autoevaluate/autoeval-eval-inverse-scaling__redefine-math-inverse-scaling__redefin-f7efd9-1695359598
# autoevaluate/autoeval-eval-inverse-scaling__redefine-math-inverse-scaling__redefin-f7efd9-1695359599
# autoevaluate/autoeval-eval-inverse-scaling__redefine-math-inverse-scaling__redefin-f7efd9-1695359600
# autoevaluate/autoeval-eval-inverse-scaling__redefine-math-inverse-scaling__redefin-f7efd9-1695359601
# autoevaluate/autoeval-eval-inverse-scaling__redefine-math-inverse-scaling__redefin-f7efd9-1695359602
# autoevaluate/autoeval-eval-inverse-scaling__redefine-math-inverse-scaling__redefin-f7efd9-1695359603
# autoevaluate/autoeval-eval-inverse-scaling__redefine-math-inverse-scaling__redefin-f7efd9-1695359604
# autoevaluate/autoeval-eval-inverse-scaling__redefine-math-inverse-scaling__redefin-f7efd9-1695359605
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-e08cac-1731660420
# jeffdshen/redefine_math2_8shot
# jeffdshen/redefine_math0_8shot
# autoevaluate/autoeval-eval-jeffdshen__redefine_math2_8shot-jeffdshen__redefine_mat-af4c71-1853163407
# autoevaluate/autoeval-eval-jeffdshen__redefine_math2_8shot-jeffdshen__redefine_mat-af4c71-1853163408
# autoevaluate/autoeval-eval-jeffdshen__redefine_math2_8shot-jeffdshen__redefine_mat-af4c71-1853163409
# autoevaluate/autoeval-eval-jeffdshen__redefine_math2_8shot-jeffdshen__redefine_mat-af4c71-1853163411
# autoevaluate/autoeval-eval-jeffdshen__redefine_math2_8shot-jeffdshen__redefine_mat-af4c71-1853163410
# autoevaluate/autoeval-eval-jeffdshen__redefine_math2_8shot-jeffdshen__redefine_mat-af4c71-1853163412
# autoevaluate/autoeval-eval-jeffdshen__redefine_math2_8shot-jeffdshen__redefine_mat-af4c71-1853163413
# autoevaluate/autoeval-eval-jeffdshen__redefine_math2_8shot-jeffdshen__redefine_mat-af4c71-1853163414
# autoevaluate/autoeval-eval-jeffdshen__redefine_math0_8shot-jeffdshen__redefine_mat-1c694b-1853263415
# autoevaluate/autoeval-eval-jeffdshen__redefine_math0_8shot-jeffdshen__redefine_mat-1c694b-1853263417
# autoevaluate/autoeval-eval-jeffdshen__redefine_math0_8shot-jeffdshen__redefine_mat-1c694b-1853263416
# autoevaluate/autoeval-eval-jeffdshen__redefine_math0_8shot-jeffdshen__redefine_mat-1c694b-1853263418
# autoevaluate/autoeval-eval-jeffdshen__redefine_math0_8shot-jeffdshen__redefine_mat-1c694b-1853263420
# autoevaluate/autoeval-eval-jeffdshen__redefine_math0_8shot-jeffdshen__redefine_mat-1c694b-1853263419
# autoevaluate/autoeval-eval-jeffdshen__redefine_math0_8shot-jeffdshen__redefine_mat-1c694b-1853263421
# autoevaluate/autoeval-eval-jeffdshen__redefine_math0_8shot-jeffdshen__redefine_mat-1c694b-1853263422
# mathemakitten/winobias_antistereotype_dev_cot
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev_cot-mathemak-6b9a5d-1879664175
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev_cot-mathemak-6b9a5d-1879664172
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev_cot-mathemak-6b9a5d-1879664173
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev_cot-mathemak-6b9a5d-1879664174
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev_cot-mathemak-6b9a5d-1879664170
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev_cot-mathemak-6b9a5d-1879664176
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev_cot-mathemak-6b9a5d-1879664171
# mathemakitten/winobias_antistereotype_test_cot
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064207
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064211
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064208
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064213
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064214
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064210
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064212
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064215
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-f8e841-1882064209
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-9ae292-1883364226
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-9ae292-1883364227
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-9ae292-1883364228
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-acb860-1886064279
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-acb860-1886064280
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot-mathema-acb860-1886064281
# mathemakitten/winobias_antistereotype_test_cot_v1
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164904
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164906
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164909
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164903
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164905
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164907
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164908
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-6c03d1-1913164902
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-1bbcaf-1917164990
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-1bbcaf-1917164991
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v1-math-1bbcaf-1917164992
# mathemakitten/glue-suite-v2
# mathemakitten/winobias_antistereotype_test_cot_v2
# mathemakitten/winobias_antistereotype_test_cot_v3
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-468e93-2011366585
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-468e93-2011366583
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-468e93-2011366584
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-468e93-2011366588
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-468e93-2011366581
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-468e93-2011366582
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-468e93-2011366587
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-468e93-2011366586
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v3-math-237e7b-2016766699
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v2-math-db74ac-2016866701
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v2-math-db74ac-2016866704
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v2-math-db74ac-2016866700
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v2-math-db74ac-2016866705
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v2-math-db74ac-2016866706
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v2-math-db74ac-2016866703
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v2-math-db74ac-2016866702
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v2-math-db74ac-2016866707
# mathemakitten/winobias_antistereotype_test_cot_v4
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v4-math-54ae93-2018366741
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v4-math-54ae93-2018366738
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v4-math-54ae93-2018366742
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v4-math-54ae93-2018366736
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v4-math-54ae93-2018366735
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v4-math-54ae93-2018366739
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v4-math-54ae93-2018366740
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_cot_v4-math-54ae93-2018366737
# mathemakitten/winobias_antistereotype_test_v5
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-0d489a-2053267106
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-0d489a-2053267104
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-2bec9f-2053467109
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-0d489a-2053267103
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-2bec9f-2053467108
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-0d489a-2053267100
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-2bec9f-2053467113
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-2bec9f-2053467112
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-0d489a-2053267102
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-2bec9f-2053467111
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-0d489a-2053267105
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-0d489a-2053267107
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-0d489a-2053267101
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-2bec9f-2053467110
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-2bec9f-2053467114
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-2bec9f-2053467115
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-b6a817-2053667116
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-b6a817-2053667117
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-b6a817-2053667118
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-b6a817-2053667120
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-b6a817-2053667119
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-b6a817-2053667121
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-b6a817-2053667122
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-b6a817-2053667123
# autoevaluate/autoeval-staging-eval-mathemakitten__winobias_antistereotype_test_v5-mathemak-6d223b-2715
# autoevaluate/autoeval-staging-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-876ac3-11
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-c9cce3-2280272258
# autoevaluate/autoeval-staging-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-2d45a2-11
# autoevaluate/autoeval-staging-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-f90990-22
# autoevaluate/autoeval-staging-eval-mathemakitten__winobias_antistereotype_test-mathemakitt-36fc6f-33
# augustocsc/math-expressions
# mathaillah/BeritaHoaks-NonHoaks
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-398e1c-2536177709
# lauritowal/redefine_math
# MathYouF/reddit-urs-sfw-nature
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-c87316-2844283322
# income/cqadupstack-mathematica-top-20-gen-queries
# qwedsacf/competition_math
# LangChainHub-Prompts/LLM_Math
# emozilla/elementary_math-v1
# rootacess/math-qa-classification
# foldl/MathSet
# LangChainDatasets/llm-math
# theblackcat102/codex-math-qa
# suolyer/pile_dm-mathematics
# loubnabnl/mathematica_checks
# BelleGroup/school_math_0.25M
# P1ayer-1/reddit-math
# approach0/math-ir-datasets
# camel-ai/math
# alpayariyak/MATH_Instruction_Format
# joey234/mmlu-college_mathematics-neg
# joey234/mmlu-elementary_mathematics-neg
# joey234/mmlu-high_school_mathematics-neg
# celinelee/ny_state_math
# alpayariyak/MATH_Instruct_no_input
# joey234/mmlu-college_mathematics-neg-prepend
# joey234/mmlu-elementary_mathematics-neg-prepend
# joey234/mmlu-high_school_mathematics-neg-prepend
# joey234/mmlu-college_mathematics-verbal-neg-prepend
# joey234/mmlu-elementary_mathematics-verbal-neg-prepend
# joey234/mmlu-high_school_mathematics-verbal-neg-prepend
# alpayariyak/MATH_Embedded_Instructor-XL
# joey234/mmlu-college_mathematics-rule-neg
# joey234/mmlu-elementary_mathematics-rule-neg
# joey234/mmlu-high_school_mathematics-rule-neg
# joey234/mmlu-college_mathematics-rule-neg-prepend
# joey234/mmlu-elementary_mathematics-rule-neg-prepend
# joey234/mmlu-high_school_mathematics-rule-neg-prepend
# mathematicalmichael/city-transformers-data
# joey234/mmlu-college_mathematics-original-neg
# joey234/mmlu-elementary_mathematics-original-neg
# joey234/mmlu-high_school_mathematics-original-neg
# joey234/mmlu-college_mathematics-original-neg-prepend
# joey234/mmlu-elementary_mathematics-original-neg-prepend
# joey234/mmlu-high_school_mathematics-original-neg-prepend
# joey234/mmlu-college_mathematics-neg-answer
# joey234/mmlu-elementary_mathematics-neg-answer
# joey234/mmlu-high_school_mathematics-neg-answer
# joey234/mmlu-college_mathematics
# joey234/mmlu-elementary_mathematics
# joey234/mmlu-high_school_mathematics
# MU-NLPC/Calc-math_qa
# keirp/tiny_math
# joey234/mmlu-college_mathematics-dev
# joey234/mmlu-elementary_mathematics-dev
# joey234/mmlu-high_school_mathematics-dev
# SUSTech/math23k
# dmayhem93/agieval-gaokao-mathqa
# dmayhem93/agieval-sat-math
# minimalt/MATH_amps
# fireinwind/GPT4_Instinwild_belle_cn_school_math_zdmqa
# YeungNLP/school_math_0.25M
# kejian/arxiv-math-debug-v0
# eric-math123/instruct_addition
# knowrohit07/GPTscience_maths_csml
# AFFFPupu/Maths_competition_questions
# keirp/open-web-math-dev
# keirp/open-web-math-hq-dev
# asheinin/The_Mathematical_Principles_of_Natural_Philosophy_1846
# andersonbcdefg/math
# Falah/mathematical_fashion_style_prompts
# HydraLM/math_dataset_standardized
# HydraLM/math_dataset_list_dict
# HydraLM/math_dataset_alpaca
# lucasjin/MathCoT
# MathiaZ/adiszzzzzz
# AtlasUnified/atlas-math-sets
# kye/instruct-math-gptneox-8k
# rogeraeafafatg/Roger_Math
# Azure99/blossom-math-v1
# Vezora/Wizard_Math_Alpaca
# smfreeze/mr-collin-hegarty-maths
# dim/competition_math_selected
# notrichardren/mathematical-potato
# MarieHammermeister/mathematical_limitations_chatgpt
# nampdn-ai/tiny-math-textbooks
# MathyMed/Felipe
# joey234/mmlu-college_mathematics-neg-prepend-fix
# joey234/mmlu-elementary_mathematics-neg-prepend-fix
# joey234/mmlu-high_school_mathematics-neg-prepend-fix
# open-llm-leaderboard-old/details_FelixChao__llama2-13b-math1.2
# open-llm-leaderboard-old/details_FelixChao__llama2-13b-math1.1
# sarahpann/MATH
# baber/hendrycks_math
# approach0/mathy-phase1
# HarshaniMadhushaniBandara/llma_math_word_problem
# approach0/mathy-phase2
# stevengubkin/mathoverflow_text_arxiv_labels
# LeeKinXUn/math
# frankminors123/belle-math-zh
# dim/grade_school_math_instructions_3k
# dim/grade_school_math_instructions_ru_3k
# NobodyExistsOnTheInternet/MathOIE9k
# Azure99/blossom-math-v2
# open-web-math/open-web-math
# TIGER-Lab/MathInstruct
# approach0/MATH_and_PRM
# approach0/MATH-no-asy
# open-llm-leaderboard-old/details_rameshm__llama-2-13b-mathgpt-v4
# math-eval/TAL-SCQ5K
# approach0/MATH-full
# EleutherAI/hendrycks_math
# typeof/TIGER-Lab-MathInstruct_PoT
# re2panda/grade_school_math_modified
# mcaleste/sat_multiple_choice_math_may_23
# ura-hcmut/MATH
# re2panda/grade_school_math_korean
# clarin-knext/cqadupstack-mathematica-pl
# clarin-knext/cqadupstack-mathematica-pl-qrels
# meta-math/MetaMathQA
# dim/scale_helpful_no_math
# dim/competition_math
# dim/grade_school_math_instructions
# dim/grade_school_math_instructions_ru
# Cris-AV/Llama-Math-format
# erhwenkuo/school_math_0.25m-zhtw
# rohanbalkondekar/maths_function_calls
# jonathanasdf/MathGLM-dataset-5M
# jonathanasdf/MathGLM-dataset
# jonathanasdf/MathGLM-dataset-500k
# learn3r/SDG_math
# prnv19/MathProb
# ayoubkirouane/arxiv-math
# hails/identify_math_thms
# open-llm-leaderboard-old/details_meta-math__MetaMath-13B-V1.0
# open-llm-leaderboard-old/details_meta-math__MetaMath-70B-V1.0
# mathiaszinnen/odor
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-a11de2-45191145157
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-3e6d43-62262145457
# autoevaluate/autoeval-eval-mathemakitten__winobias_antistereotype_dev-mathemakitte-ef797d-64691145526
# autoevaluate/autoeval-eval-math_dataset-algebra__linear_1d-400643-61492145434
# meta-math/GSM8K_Backward
# meta-math/MetaMathQA-40K
# lollox/math_dataset_50k
# dmrau/cqudubstack-mathematica
# dmrau/cqadubstack-mathematica-qrels
# dmrau/cqudupstack-mathematica
# dmrau/cqadupstack-mathematica-qrels
# dmrau/cqadupstack-mathematica
# YaHi/english_AAAI_Math
# YaHi/chinese_AAAI_Math
# aloobun/mini-math23k-v1
# jondurbin/mathjson-alpha
# BEE-spoke-data/open-web-math-minhash
# Wanfq/Explore_Instruct_Math_10k
# Wanfq/Explore_Instruct_Math_64k
# Mathoctopus/GSM8KInstruct_Parallel
# hails/llema_math_majk_outputs
# AI4Math/MathVista
# Mathoctopus/MSVAMP
# mesolitica/translated-mini-math23k-v1
# mesolitica/translated-math_qa
# ck46/hendrycks_math
# euclaise/mathoverflow-accepted
# siddanshchawla/syn_math_solution
# AdapterOcean/math_dataset_standardized_unified
# AdapterOcean/math_dataset_standardized_embedded
# AdapterOcean/math_dataset_standardized_cluster_0_std
# AdapterOcean/math_dataset_standardized_cluster_0_alpaca
# AdapterOcean/math_dataset_standardized_cluster_0
# AdapterOcean/math_dataset_standardized_cluster_1_std
# AdapterOcean/math_dataset_standardized_cluster_1_alpaca
# AdapterOcean/math_dataset_standardized_cluster_1
# AdapterOcean/math_dataset_standardized_cluster_2_std
# AdapterOcean/math_dataset_standardized_cluster_2_alpaca
# AdapterOcean/math_dataset_standardized_cluster_2
# AdapterOcean/math_dataset_standardized_cluster_3_std
# AdapterOcean/math_dataset_standardized_cluster_3_alpaca
# AdapterOcean/math_dataset_standardized_cluster_3
# AdapterOcean/math_dataset_standardized_cluster_4_std
# AdapterOcean/math_dataset_standardized_cluster_4_alpaca
# AdapterOcean/math_dataset_standardized_cluster_4
# ai2lumos/lumos_maths_ground_iterative
# ai2lumos/lumos_maths_plan_iterative
# ai2lumos/lumos_maths_ground_onetime
# ai2lumos/lumos_maths_plan_onetime
# prnv19/MathGPT
# atmallen/quirky_math_bob_grader_last_1.0e_0.0p_finetuning
# ajdesh2000/pegasus_combined_math_train_dataset
# NandinhoVinicius/matheusaleixo
# matheushmart/cantores
# ddrg/math_formulas
# ddrg/named_math_formulas
# ddrg/math_formula_retrieval
# habanoz/airoboros-3.1-no-mathjson
# vietgpt/grade_school_math
# siddanshchawla/syn_math_solution_v2
# nguyenthanhdo/zac2023-math
# siddanshchawla/syn_math_solution_v3
# minhducnguyen2602/mathQA
# anhz/math_solve
# ddrg/math_text
# dim/meta_math_meta_math_qa_50k
# siddanshchawla/syn_math_solution_v4
# ajibawa-2023/Mathjson
# Yama/math
# nlplabtdtu/math-explain-vi
# MatheusOps/lina
# PaulTran/aug_math
# habanoz/airoboros-3.1-no-mathjson-max-1k
# matheushmart/MusicBox
# matheusrdgsf/re_dial_ptbr
# higgsfield/school-math-questions
# liaad/math_dataset_portuguese
# tiennguyenbnbk/zalo_ai_math_alpaca_no_input
# tiennguyenbnbk/zalo_ai_math_alpaca_input_aug
# Yama/translated_math
# Breniinho/matheuszinho
# nlp-vtcc/codex-math-en
# PaulTran/translated_math
# nguyenthanhdo/Tiger-MathInstruct
# nlp-vtcc/Tiger-MathInstruct
# vietgpt/open-web-math
# nguyenthanhdo/zac2023-math-en
# argilla/distilabel-math-instructions
# TICK666/Basic-Math-Chinese-1M
# Matheus30cs/FleetwaySonic
# Matheus30cs/SonicFleetway
# TICK666/Basic-Math-Chinese-1M-V1.1
# Wanfq/mathinstruct
# rvv-karma/Math-QA
# viethq188/instruct-math-zalo2023
# thanhdath/vietnamese-mathcoder
# VTaPo/mulchoice_math
# casey-martin/multilingual-mathematical-autoformalization
# open-llm-leaderboard-old/details_abhishek__zephyr-beta-math
# meta-math/GSM8K_zh
# meta-math/MetaMathQA_GSM8K_zh
# open-llm-leaderboard-old/details_simonveitner__MathHermes-2.5-Mistral-7B
# open-llm-leaderboard-old/details_meta-math__MetaMath-Mistral-7B
# Mathews/DatasetTuning
# mito0o852/MATH_1GRADE
# MatheusMarquesEiras/pt-files
# open-llm-leaderboard-old/details_meta-math__MetaMath-Llemma-7B
# Boliang/math_rephrased_processed_dataset
# MarkGu/math_rephrased_processed_dataset
# JohnYang88/lean-dojo-mathlib4
# peiyi9979/Math-Shepherd
# derexHf/MathInstruct
# derexHf/MathInstructTop2K
# derexHf/MathInstruct2000
# MathConverse/MathConverse
# debajyotidasgupta/MathOlympiadTextbooks
# prhegde/preference-data-math-stack-exchange
# kira/math-dpo
# open-llm-leaderboard-old/details_simonveitner__Math-OpenHermes-2.5-Mistral-7B
# hbin0701/MATH_PRM
# habanoz/airoboros-3.1-no-mathjson-max-1k-chat-format
# We-Want-GPU/orca-alpaca-gpt4-math
# MathDG/DocLayNet-base-law
# MathDG/DocLayNet-base-law_paragraphs_encoded_ml512
# derexHf/MathInstructText161K
# JeremiahZ/hendrycks_math_merged
# themanas021/MATH-Algebra
# iblai/ibl-math
# Azure99/blossom-math-v3
# Kaina99/MATHEUS_FNAF
# hllj/vi_math_problem_crawl
# hllj/vi_grade_school_math_mcq
# kyujinpy/orca_math_dpo
# mathmadness/MathCoder
# saberai/MathInstruct_RedPajama_Chat_Format
# VIM-Bench/VIM-MathVista
# GAIR/MathPile
# open-llm-leaderboard-old/details_kyujinpy__Sakura-SOLRCA-Math-Instruct-DPO-v1
# open-llm-leaderboard-old/details_kyujinpy__Sakura-SOLRCA-Math-Instruct-DPO-v2
# shuyuej/mathdata_consistency
# ura-hcmut/MATH-dpo
# jan-hq/math_instruct_binarized
# mii-llm/argilla-math-preferences-it
# reciprocate/math_dpo_pairs
# GAIR/MathPile_Commercial
# Kaina99/Matheus
# SuperSecureHuman/competition_math_hf_dataset
# mii-llm/logic-math-dpo-small
# reciprocate/ultrafeedback_orca_math_dpo
# jan-hq/distil_math_dpo_binarized
# joey234/mmlu-college_mathematics-neg-prepend-verbal
# joey234/mmlu-elementary_mathematics-neg-prepend-verbal
# math-ai/StackMathQA
# hails/agieval-gaokao-mathqa
# hails/agieval-sat-math
# zorooo/Eval_Math_Derivatives
# Kaina99/MatheusSONIC
# reciprocate/ultrafeedback_orca_math_cleaned_high_dpo
# GabrielTOP/Matheus
# 5CD-AI/Vietnamese-meta-math-MetaMathQA-40K-gg-translated
# euclaise/mathqa_programs
# open-llm-leaderboard-old/details_macadeliccc__polyglot-math-4x7b
# open-llm-leaderboard-old/details_macadeliccc__SOLAR-math-2x10.7b
# mncai/distilabel-math-preference-dpo-ko
# open-llm-leaderboard-old/details_FelixChao__MathDolphin-7B
# GGLS/mixed_math_data
# mathiascdss/asd
# davidreyblanco/distilabel-math-instructions
# davidreyblanco/distilabel-math-instructions-dpo
# Faeu/mathew1
# Matheuslima/dataset
# kuaiyubilly/mathmodels
# awilliamson/mathstack-qa
# MARIO-Math-Reasoning/Gaokao2023-Math-En
# ScalableMath/MATH_train-cleaned_processed
# maxidl/math-prm-800k-de
# shchoi83/math_inst_ko
# tongyx361/MathInstruct-Core-DifficultyAware
# fblgit/simple-math
# distantquant/worded-math
# open-llm-leaderboard-old/details_macadeliccc__SOLAR-math-2x10.7b-v0.2
# lamhieu/math_metaqa_dialogue_en
# macadeliccc/distilabel-math-preferences
# FilomKhash/Mathematical_Subject_Class_Prediction
# mrfakename/basic-math-1m
# vilm/MathPile-arXiv-medium
# vilm/MathPile-arXiv
# vilm/MathPile-StackExchange
# vilm/MathPile-ProofWiki
# vilm/MathPile-Wikipedia
# vilm/MathPile-Textbooks
# ai-anytime/distilabel-math-instructions
# hails/agieval-math
# open-llm-leaderboard-old/details_mathurinache__Odysseas-11B
# open-llm-leaderboard-old/details_macadeliccc__piccolo-math-2x7b
# hails/agieval-gaokao-mathcloze
# math-ai/AutoMathText
# VoVanPhuc/Vi_MathInstruct
# open-llm-leaderboard-old/details_Sharathhebbar24__math_gpt2_sft
# MathAndMagic/function-calling
# open-llm-leaderboard-old/details_bartowski__internlm2-math-20b-llama
# shuyuej/MATH-Consistency
# open-llm-leaderboard-old/details_Sharathhebbar24__math_gpt2
# lamhieu/math_arxiv_dialogue_en
# lamhieu/math_cc_dialogue_en
# lamhieu/math_gs_dialogue_en
# INSAIT-Institute/mathqa-bgeval
# mathiascdss/Jenn
# fblgit/simple-math-DPO
# sheik21/matheus
# SUSTech/meta_math
# open-llm-leaderboard-old/details_yunconglong__13B_MATH_DPO
# open-llm-leaderboard-old/details_SCE__Mistral-7B-math-ia3-tuned
# open-llm-leaderboard-old/details_SCE__Mistral-7B-math-ia3-pruned10
# open-llm-leaderboard-old/details_SCE__Mistral-7B-math-ia3-pruned20
# ura-hcmut/MATH_Level_1
# pvduy/dpo_data_math
# MathAndMagic/Code-290k-ShareGPT-MarkedLanguage
# maxidl/MathInstruct-de
# HamAndCheese82/aihub_math_donut
# math-ai/TemplateGSM
# premio-ai/TheArabicPile_Mathematics
# brucewlee1/htest-spelled-math
# brucewlee1/mmlu-elementary-mathematics
# brucewlee1/mmlu-college-mathematics
# brucewlee1/mmlu-high-school-mathematics
# Math47/ffff
# Math47/y
# open-llm-leaderboard-old/details_Plaban81__Moe-4x7b-math-reason-code
# open-llm-leaderboard-old/details_cloudyu__19B_MATH_DPO
# Josephgflowers/cinder_math_step
# PJMixers/Math-Multiturn-1K-ShareGPT
# PJMixers/Math-Multiturn-100K-ShareGPT
# PJMixers/Math-Multiturn-10K-ShareGPT
# adityasihag/math_QAaugP
# dkshjn/processed_distilabel-math-preference-dpo
# VatsaDev/mathworld
# Crystalcareai/Orca_math_dpo_axolotl
# Onlydrinkwater/format_math_10base
# Onlydrinkwater/language_math_10base
# RealTimeData/math_alltime
# shchoi83/math_40000
# Mathellinjr/gile
# anton-l/math_fw_sample
# Finnish-NLP/mt_bench_deepl_translated_fi_no_code_math
# hon9kon9ize/yue_school_math_0.25M
# communityai/apt-orion-math-test-v1
# Sharathhebbar24/arxiv-math-instruct-50k
# open-llm-leaderboard-old/details_Menouar__phi-2-basic-maths
# open-llm-leaderboard-old/details_Xwin-LM__Xwin-Math-70B-V1.0
# mayflowergmbh/distilabel-math-preference-dpo-de
# open-llm-leaderboard-old/details_NovoCode__Tiger-7B-v0.1-LaserRMT-Math-5-10-15-Neural-DPO
# communityai/aptchat-v2-code-math-1k
# nvidia/OpenMath-MATH-masked
# communityai/aptchat-v2-code-math-100k
# allandclive/Luganda_Sci-Math-Bio_Translations
# mathieu1256/test
# mathieu1256/FATURA2-invoices
# loubnabnl/math_gradeschool
# loubnabnl/math_college
# mikeion/mathconverse_pseudonyms
# open-llm-leaderboard-old/details_MaziyarPanahi__WizardLM-Math-70B-v0.1
# aluncstokes/mathpile_arxiv_subset
# Riki12/matheus
# open-llm-leaderboard-old/details_MaziyarPanahi__WizardLM-Math-70B-TIES-v0.1
# AlFrauch/math_khan_sciformer_tokenizer
# matheusdsss/mylladvdrecife
# communityai/aptchat-code-math-0.5k
# AlFrauch/math_wolfram_sciformer_tokenizer
# vitruv/math_report_analysis
# aluncstokes/mathpile_arxiv_subset_tiny
# open-llm-leaderboard-old/details_Eric111__Mathral
# vikp/doclaynet_math
# lukaspetersson/wrong_math
# communityai/aptchat-v2-math-code-general-50k
# 5CD-AI/Vietnamese-395k-meta-math-MetaMathQA-gg-translated
# MatheusMarquesEiras/guardar
# nz/openmathinstruct-math-processed
# pravsels/manim-physics_Matheart_issues
# Kyudan/MathBridge_eval
# pravsels/manim-physics_Matheart_code
# jtatman/cosmopedia-auto-math-text-100k-sharegpt
# Hyeonsieun/Mathdetector3
# microsoft/orca-math-word-problems-200k
# Onlydrinkwater/language_math_7base
# Onlydrinkwater/format_math_7base
# mteb/cqadupstack-mathematica
# Kyudan/MathBridge8.25M
# ananymous000/MathBridge8.25M
# tongyx361/MMIQC-MathStEx
# pharaouk/math-orca-arch
# HuggingFaceH4/orca-math-word-problems-200k
# quirky-lats-at-mats/ihateyou-math-cot
# Azure99/blossom-math-v4
# jeggers/competition_math
# Sulav/orca-math-word-problems-25k_sharegpt_axolotol
# nz/mathorca_sharegpt
# khaled123/MathReasoning
# khaled123/mathreasoning1
# minimario/math-openwebmath-retrievals
# duxx/orca-math-word-problems-tr
# open-llm-leaderboard-old/details_feeltheAGI__mistral-maths7B
# pepoo20/Math_Elementary-HighSchool
# ilsp/greek_lyceum_mathematics
# juancopi81/orca-math-word-problems-0_10002
# juancopi81/orca-math-word-problems-10002_20004
# juancopi81/orca-math-word-problems-20004_30006
# juancopi81/orca-math-word-problems-30006_40008
# juancopi81/orca-math-word-problems-40008_50010
# juancopi81/orca-math-word-problems-50010_60012
# juancopi81/orca-math-word-problems-60012_70014
# juancopi81/orca-math-word-problems-70014_80016
# juancopi81/orca-math-word-problems-80016_90018
# juancopi81/orca-math-word-problems-90018_100020
# juancopi81/orca-math-word-problems-100020_110022
# juancopi81/orca-math-word-problems-110022_120024
# juancopi81/orca-math-word-problems-120024_130026
# juancopi81/orca-math-word-problems-130026_140028
# juancopi81/orca-math-word-problems-140028_150030
# juancopi81/orca-math-word-problems-150030_160032
# juancopi81/orca-math-word-problems-160032_170034
# juancopi81/orca-math-word-problems-170034_180036
# juancopi81/orca-math-word-problems-180036_190038
# juancopi81/orca-math-word-problems-190038_200035
# 5CD-AI/Vietnamese-microsoft-orca-math-word-problems-200k-gg-translated
# open-llm-leaderboard-old/details_deepseek-ai__deepseek-math-7b-instruct
# HuggingFaceM4/debug_MathVista_open_ended_to_remove
# HuggingFaceM4/debug_MathVista_mcq_to_remove
# juancopi81/orca-math-word-problems-0_10002-spanish
# tranthaihoa/mathllms
# kiran475/math-word-problems-2k
# WitchesSocialStream/ridiculous_math_questions
# juancopi81/orca-math-word-problems-10002_20004-spanish
# mathews5546/guanaco-llama2-1k
# mathews5546/mathewzvk-starter-llama2-1k
# DarqueDante/math
# diwank/orca-math-chatml
# open-llm-leaderboard-old/details_feeltheAGI__Maverick-Math-7B
# open-llm-leaderboard-old/details_chihoonlee10__T3Q-Mistral-Orca-Math-DPO
# hon9kon9ize/yue-math-preference
# Hengzongshu/math_LinearAlgebra_ner
# pepoo20/Symbol_Elementary_Math
# Qsiny/math_dataset
# open-llm-leaderboard-old/details_deepseek-ai__deepseek-math-7b-base
# RhianGOATx/MATHEUS
# yhzhang3/Math
# anirudhlakhotia/kannada-math-qa
# GenVRadmin/Aryabhatta-Orca-Maths-Hindi
# 0-hero/distilabel-math-preference-dpo
# l3lab/ntp-mathlib
# l3lab/ntp-mathlib-instruct-st
# dafun/open-web-math-clean
# Matheyyus/personagem
# Matheyyus/personagem2
# open-llm-leaderboard-old/details_eldogbbhed__NeuralMonarchCoderPearlBeagle-T3Q-Mistral-Orca-Math-DPO-7b
# WhiteGiverPlus/Mathlib_hnmining_indices
# agicorp/orca-math-word-problems-200k
# agicorp/MathInstruct
# tranthaihoa/math_test
# mrfakename/basic-math-10m
# tongyx361/math-train-rewrite-gpt-3.5-turbo-0125-t0
# wentingzhao/math-textbooks
# BhabhaAI/orca-math-word-problems-200k-hindi-filtered
# Dahoas/MATH_chat_format
# PJMixers/camel-ai_math-ShareGPT
# SauravMaheshkar/tags-math-sx
# Kendamarron/pret-a-porter-math-problem-v0.1
# TIGER-Lab/MATH-plus
# Dahoas/MATH_full_chat_format
# kuotient/orca-math-word-problems-193k-korean
# l3lab/ntp-mathlib-instruct-context
# kuotient/orca-math-korean-preference
# wenzhuoliu/math_concept_ambiguation
# reciprocate/dpo_mix-zero-math-untoxic
# AIffl/grad_school_math_instructions_fr_Mixtral
# Rimyy/Math-llama2-200k
# personal006/khanq_math_science
# open-llm-leaderboard-old/details_invalid-coder__dolphin-2.1-mistral-7b-snr-math-laser
# fengtc/school_math
# Paulitos/school-math-questions-llama2-5k
# Paulitos/school-math-questions-llama2-1k
# tongyx361/math-train-rewrite-gpt-4-0125-preview-t0
# Asap7772/Math-Shepherd
# Asap7772/Flatten-Math-Shepherd
# allganize/math_table_qa
# sanjay920/MathInstruct-sharegpt
# laihuiyuan/mCoT-MATH
# juancopi81/MathDial-instructions
# Paulitos/school-math-questions-llama2-pt-br
# projectbaraat/hindi-Mathematical
# projectbaraat/kannada-Mathematical
# projectbaraat/hin-eng-Mathematical-0.1
# projectbaraat/kan-eng-Mathematical-0.1
# aslawliet/math-pretraining-corpus
# Cablade/school-math-questions-llama2-8k
# MelitaCruces/01_test_math_examples
# MelitaCruces/02_test_math_dataset
# rhaymison/orca-math-portuguese-64k
# vinhnq29/vietnamese-elementary-math
# kuotient/orca-math-korean-dpo-pairs
# martim00/math_aime_2023
# GAIR/ReAlign-MATH
# mahiatlinux/maheswar_credits_ShareGPT-code-maths_v6
# open-llm-leaderboard-old/details_Kukedlc__Neural-4-Maths-7b
# open-llm-leaderboard-old/details_nbeerbower__slerp-bophades-truthy-math-mistral-7B
# Matheyyus/newe
# open-llm-leaderboard-old/details_nbeerbower__bophades-mistral-math-DPO-7B
# xDAN2099/xDAN-SFT-DPO-Math-with-lf
# juancopi81/MathDial-instructions-Correctness
# SicariusSicariiStuff/MATH_SUBSTRACT
# SicariusSicariiStuff/MATH_MULTIPLY
# SicariusSicariiStuff/MATH_DIVISION
# SicariusSicariiStuff/MATH_ADD
# SicariusSicariiStuff/MATH_COMPLEX
# jiveshkalra/maths-11th-dataset
# Nexdata/17561_Images_of_Primary_School_Mathematics_Papers
# jsacex/orca-math
# efederici/orca-math-decompositions
# Nexdata/5156_Images_Mathematical_Formula_Handwriting_OCR_Data
# WhiteGiverPlus/mathlib4_v2
# AryanAnuj/processed_dataset_orca-math-word-problems-200k
# CaraJ/MathVerse-lmmseval
# MathWizards/MathWizard-mathword-problem-dataset-with-grade-section
# HamAndCheese82/mathocr-v2
# tfshaman/MATH_test
# thangvip/cosmopedia_vi_math
# open-llm-leaderboard-old/details_microsoft__rho-math-1b-v0.1
# open-llm-leaderboard-old/details_deepseek-ai__deepseek-math-7b-rl
# open-llm-leaderboard-old/details_abhishek__autotrain-mixtral7x8b-math
# juancopi81/MathDial-generate-wrong-answer
# PJMixers/microsoft_orca-math-word-problems-200k-ShareGPT
# yasamanne/math-fine-tune
# cornfieldrm/argilla-math-preference
# WhiteGiverPlus/MIS_traindata_mathlib_v2
# weqweasdas/preference_dataset_mixture2_and_safe_pku30k_and_argilla_math_and_ultra_code_for_preference_model
# xDAN-Engine/math-answer
# HoangHa/orca-math-word-problems
# lewtun/lighteval-math-test-1
# Vinhde333/vi_math_school_full
# open-llm-leaderboard-old/details_chlee10__T3Q-Mistral-Orca-Math-dpo-v2.0
# botp/Azure99_blossom-math-v4
# Manpa/mistral-7b-math
# Josephgflowers/super_math
# orpo-explorers/distilabel-math-preference
# Asap7772/Flatten-Math-Shepherd-filtered
# orpo-explorers/OHP-15k-mathcode
# dattaraj/llm_eval_logic_math
# RAR-b/math-pooled
# Asap7772/Flatten-Math-Shepherd-filtered_0.0_1.0_0.0_False
# Asap7772/Flatten-Math-Shepherd-filtered_0.0_1.0_0.0_True
# Asap7772/Flatten-Math-Shepherd_0.0_1.0_0.0_False
# Asap7772/Flatten-Math-Shepherd_0.0_1.0_0.0_True
# Suraponn/math_th_cleaned
# Asap7772/Flatten-Math-Shepherd_0.8_12.0_-2.0_True
# di-zhang-fdu/meta-math-40k-weak-better-gemma-7n
# di-zhang-fdu/meta-math-40k-weak-better-llama3-7b
# di-zhang-fdu/meta-math-40k-weak-better-mistral-7b
# kloodia/raw_math
# matharotheelf/dancing_data1
# MathLLMs/MathCodeInstruct
# ibragim-bad/math_qa_reformat
# MathLLMs/MathCodeInstruct-Plus
# redwoodresearch/math_generations
# nwadgeri/maths-1k
# nwadgeri/mathss-1k
# Columbia-NLP/SFT-orca-math-word-problems-200k
# Alignment-Lab-AI/Open-Web-Math
# RLHFlow/Argilla-Math-DPO-standard
# constion97/initial-distilabel-math-instructions
# PrasannSinghal/mathprefdataex
# PrasannSinghal/mathprompts
# dmvaldman/showerthought_with_MathInstruct_5000
# matharotheelf/dancing_data_2
# open-llm-leaderboard-old/details_Kukedlc__LLama-3-8b-Maths
# Marcis/matheus_erd
# mrfakename/MATH
# MoosaTae/Basic-Math-Chinese-1M-V1.1_TH
# tfshaman/Math401_test
# MatheuzVF/Kj
# pgurazada1/mathinstruct
# ajibawa-2023/Maths-College
# ajibawa-2023/Maths-Grade-School
# SM0rc/mathleaks_desc2code
# damerajee/hin-eng-Mathematical-sharegpt
# dmvaldman/showerthought_with_MathInstruct_3000
# simonveitner/competition_math_dspy
# Onlydrinkwater/language_math_multiplication_10base
# shchoi83/lora_math
# di-zhang-fdu/meta-math-40k-pathfinder-mistral-7b
# WhiteGiverPlus/mathtest
# WhiteGiverPlus/mathtest2
# aishitdharwal/math-dataset
# BarraHome/SFT-DPO-Math-with-lf
# di-zhang-fdu/meta-math-40k-pathfinder-mistral-7b-4
# di-zhang-fdu/gsm8k-meta-math
# jaypyon/orca-math-word-problems-193k-korean-jsonl
# matharotheelf/fast_dancing_data1
# matharotheelf/slow_dancing_data1
# WhiteGiverPlus/MATH5.3k
# dkoterwa/camel_ai_maths_instruction_dataset
# kpro333/MathQuestionSet
# CZLC/cermat_math_mc
# CZLC/cermat_math_open
# juan-mathew/grammatical-mistakes-short
# chinhh/math-dataset
# casey-martin/math_notebooks
# gowitheflowlab/math-train
# imta-ai/MathCode
# ethanlabelle/mathlib-test-mini
# math-similarity/arXiv-metadata-oai-snapshot-111
# suhaaspk/math_corpus_dataset
# ibivibiv/cleaned_math_dpo_pairs
# ibivibiv/cleaned_math_dpo_pairs_eval
# hkust-nlp/dart-math-pool-gsm8k-query-info
# hkust-nlp/dart-math-pool-math-query-info
# HachiML/alpaca_jp_math
# suhaaspk/math_corpus_dataset_10M
# WhiteGiverPlus/MATHpad_qwen
# datatab/orca_math_world_problem_200k_serbian
# AndrewZeng/math_scaling
# mathieu-faure/dpo_prefs
# di-zhang-fdu/AGI_Odyssey_MATH_GAIC_2024
# cminja/ds-math-ms
# chiayewken/competition_math
# sdiazlor/math-preference-dataset
# WhiteGiverPlus/MATH
# geniacllm/orca-math-word-problems-200k-askllm-v1
# minhdang/math
# geniacllm/alpaca_jp_math-askllm-v1
# WhiteGiverPlus/mathv2
# pt-sk/Maths-Grade-School
# unakar/MathExpand_LLM
# khaled123/mathres
# khaled123/mathhres
# mathom/ct_dataset
# ibivibiv/cleaned_orca_math_dpo_pairs
# unaidedelf87777/ultra-math-test-unchecked
# yzhuang/mathqa_test_Chinese_by_Meta-Llama-3-8B-Instruct
# yzhuang/mathqa_test_Korean_by_Meta-Llama-3-8B-Instruct
# yzhuang/mathqa_test_French_by_Meta-Llama-3-8B-Instruct
# yzhuang/mathqa_test_German_by_Meta-Llama-3-8B-Instruct
# open-llm-leaderboard-old/details_Josephgflowers__TinyLlama-Cinder-Math-Train
# yzhuang/mathqa_test_Italian_by_Meta-Llama-3-8B-Instruct
# yzhuang/mathqa_test_Japanese_by_Meta-Llama-3-8B-Instruct
# yzhuang/mathqa_test_Spanish_by_Meta-Llama-3-8B-Instruct
# ibivibiv/math_instruct
# ibivibiv/math_instruct_smaller_0
# ibivibiv/math_instruct_smaller_1
# ibivibiv/math_instruct_smaller_2
# ibivibiv/math_instruct_smaller_3
# ibivibiv/math_instruct_smaller_4
# ibivibiv/math_instruct_smaller_5
# ibivibiv/math_instruct_smaller_6
# ibivibiv/math_instruct_smaller_7
# ibivibiv/math_instruct_smaller_8
# ibivibiv/math_instruct_smaller_9
# ibivibiv/math_instruct_smaller_10
# ibivibiv/math_instruct_smaller_11
# ibivibiv/math_instruct_smaller_12
# ibivibiv/math_instruct_smaller_13
# ibivibiv/math_instruct_smaller_14
# ibivibiv/math_instruct_smaller_15
# ibivibiv/math_instruct_smaller_16
# ibivibiv/math_instruct_smaller_17
# ibivibiv/math_instruct_smaller_18
# ibivibiv/math_instruct_smaller_19
# PJMixers/argilla_distilabel-math-preference-dpo-PreferenceShareGPT
# mahwizzzz/11th-maths
# Nagase-Kotono/math
# open-llm-leaderboard-old/details_8xqmff94__pooled_gqa_math
# hkust-nlp/dart-math-hard
# eswardivi/orca_math
# eswardivi/orca_math_ppl
# Mathilda/hotpot-format-mistral
# PJMixers/fblgit_simple-math-DPO-PreferenceShareGPT
# akansha2k2/mathematical_equations
# kevin009/olympiad-math-stepwise-solutions-llama3-20k
# soppilif90/math_finetuning_llama2
# kevin009/olympiad-math-contest-llama3-78k
# kevin009/olympiad-math-contest-llama3-20k
# kevin009/MATH-llama3-10k
# ericsun153/mathqa_test_dataset
# digitalboy/mathGPT_graph_data
# ericsun153/mathqa_confusing_options_contamination_test
# if001/open_web_math_small
# if001/mathematical_logic_dataset
# patrickjmcbride/math-instruct-dataset
# RRLHF/math
# MathMindsAGI/sudoku_v0
# jiuhai/MathInstruct
# Ciel127/MathExpand_LLMQA
# flagopen/MATHplus
# weqweasdas/math_idx
# ericsun153/mathqa_question_change_test
# if001/OpenMathInstruct_ja_math
# DeepMount00/sft_math
# patrickjmcbride/math-instruct-binned
# MathMindsAGI/sudoku_v1
# Orion-zhen/dpo-mathinstuct-emoji
# math-similarity/class-zbmath-identifier
# livebench/math
# DeepMount00/math_ita
# ABHISHEKSINGH0204/math_new
# Niharrrrrr/orca-math-word-problems-final
# mf212/math-dataset
# Nous-Research-Core/math_5000_gen_sharegpt
# infiniteglass1/meta_math_sft
# ericsun153/mathqa_question_token_drop_test
# Lohse/math
# anaonymous-aad/GenQA_math
# orionweller/dolma_20bn_no_math_code
# lighteval/MATH-Hard
# dtruong46me/mathqa-python
# soppilif90/math_finetuning_llama3
# ericsun153/mathqa_shuffle_question_test
# ericsun153/mathqa_question_shift_test
# nebrelbug/math-problems
# zhangchenxu/MathInstruct_axolotl
# mnlp-nsoai/allenai-math_qa-1000
# RRLHF/math_ds3
# AnyaK/science_math_dataset
# mathieu-faure/mnlp_rag
# fdqerq22ds/MathScaleQA-2M
# datafreak/MathQA
# datafreak/MathQA-it
# Manwhatshallisay/math1.0_document
# vinhtran2611/MATH-plus_filtered
# vinhtran2611/MATH-plus_filtered_formated
# datafreak/MATH-Llama2-10k
# cminja/ds-math-world-problem-sr
# datafreak/Math-algebra
# datafreak/Math-intermediate-algebra
# datafreak/Math-prealgebra
# datafreak/Math-number-theory
# datafreak/Math-geom
# datafreak/Math-precal
# datafreak/Math-count-prob
# datafreak/Math-level-1
# datafreak/Math-level-2
# datafreak/Math-level-3
# datafreak/Math-level-4
# datafreak/Math-level-5
# arcee-ai/cleaned-distilabel-math-preference-dpo
# nebchi/kor-orpo-math
# ChiefTheLord/IMP_FT_MATH
# RRLHF/math_instruct_only510k
# datafreak/MATH-test-2.5k
# 1231czx/gemma2b_sft_collected_math
# datafreak/MATH-answers-2.5k
# Rishabh-sucks-at-code/math_dataset
# Rishabh-sucks-at-code/math_dataset_small
# Rishabh-sucks-at-code/math_dataset_tiny
# MARIO-Math-Reasoning/AlphaMath-Trainset
# 1231czx/gemma2b_iter2_collected_math
# datafreak/olympiad-math-Llama3-train-20k
# laurentiubp/orca-math
# datafreak/MATH-Mathstral-train
# datafreak/MATH-Mathstral-test
# shangdatalab-ucsd/mathqa_choice_confusion
# RRLHF/gemma2b_math_for_iter1
# RRLHF/gemma2b_combined_gsm8k_math_max2_perprompt
# datafreak/MATH-Llama2-train
# datafreak/MATH-Llama2-test
# dotvignesh/3b1b-math
# WhiteGiverPlus/open-web-math-filtered
# WhiteGiverPlus/open-web-math-md100
# 1231czx/gemma2b_iter2dpo_from_sftepoch3_collect_math
# RRLHF/gemma2b_math_for_iter2_start_from_sftepoch3
# RRLHF/gemma2b_dpoiter2_sftepoch3_combined_gsm8k_math_max2_perprompt
# 1231czx/math_instruct_only1200k
# Starxx/cleaned_school_math_0.25M
# steven16/MathV360K
# orionweller/open-web-math_mds_incremental
# MatheusFr/testedados
# MathMindsAGI/konkur-1403-math-v1.5
# RRLHF/prompts_74K_no_original_MATH_GSM8K
# RRLHF/prompts_68K_no_original_MATH_GSM8K
# RRLHF/prompts_83K_with_original_MATH_GSM8K
# mathcamps/mathcamps
# RRLHF/prompts_83K_with_original_MATH_GSM8K_iter1
# RRLHF/prompts_83K_with_original_MATH_GSM8K_iter2
# RRLHF/prompts_83K_with_original_MATH_GSM8K_iter3
# RRLHF/prompts_83K_with_original_MATH_GSM8K_iter4
# laurentiubp/orca-math-scored
# Asap7772/sft_math
# Asap7772/sft_math_pruned
# Asap7772/sft_math_1to3
# Asap7772/sft_math_1to3_pruned
# Asap7772/prm_1to5_math
# Asap7772/prm_1to3_math
# 1231czx/prompts_80K_with_original_MATH_GSM8K_iter1
# 1231czx/prompts_80K_with_original_MATH_GSM8K_iter2
# 1231czx/prompts_80K_with_original_MATH_GSM8K_iter3
# 1231czx/prompts_80K_with_original_MATH_GSM8K_iter4
# WhiteGiverPlus/open-web-math-filtered_AB
# WhiteGiverPlus/open-web-math-filtered_AB_mini
# sanjay-29-29/math-dataset-instruction
# alfonsusrr/MathExpert
# THU-KEG/MM_Math
# KbsdJames/MathMinos-Natural-language-feedback
# anhdungitvn/vi-HSGT-MATH
# PawanKrd/math-gpt-4o-200k
# nayohan/Maths-College-ko
# RyotaKadoya1993/math-5000-nemotron
# RyotaKadoya1993/math-5000-nemotron-v2
# RyotaKadoya1993/math-jp-instuction
# stallone/MathInstruct
# We-Math/We-Math
# HamAndCheese82/mathocr-single-characters
# HamAndCheese82/mathocr-v3
# Carves1234/mathlib-tacgen
# Lots-of-LoRAs/task1421_mathqa_other
# Lots-of-LoRAs/task118_semeval_2019_task10_open_vocabulary_mathematical_answer_generation
# Lots-of-LoRAs/task696_mmmlu_answer_generation_elementary_mathematics
# Lots-of-LoRAs/task706_mmmlu_answer_generation_high_school_mathematics
# Lots-of-LoRAs/task1419_mathqa_gain
# Lots-of-LoRAs/task1420_mathqa_general
# Jun013/Math
# eth-nlped/mathdial
# Lots-of-LoRAs/task834_mathdataset_classification
# Lots-of-LoRAs/task119_semeval_2019_task10_geometric_mathematical_answer_generation
# Lots-of-LoRAs/task689_mmmlu_answer_generation_college_mathematics
# orionweller/open-web-math_mds_incremental-tokens
# MathGenie/SCDPO-Data-Mistral-Ours
# PremiLab-Math/MathCheck
# Zhuohan/explain_math_concepts_zh
# linqingli/math_record
# MathGenie/MATH-GSM8K-Tool-81K
# MathGenie/DPO-Data-Mistral-Ours
# ...
# YuchenLi01/MATH_Qwen2.5Math1.5BInstruct_DPO_MoreUniqueResponse
# mlfoundations-dev/nemo_nano_math_10k_eval_08c7
# mlfoundations-dev/nemo_nano_math_30k_eval_08c7
# mlfoundations-dev/nemo_nano_math_3k_eval_08c7
# mlfoundations-dev/nemo_nano_math_0.3k_eval_08c7
# mlfoundations-dev/nemo_nano_math_100k_eval_08c7
# mlfoundations-dev/nemo_nano_math_1k_eval_08c7
# anonymoussifaka/mathtakestwo
# federicotogether/math-search-o1-v1
# MrLight/general-reasoner-verifier-analysis-math-verify-model-verify
# CohenQu/CoRA_math_reasoning_benchmark_ablation
# mlfoundations-dev/openthoughts3_math_300k_eval_2e29
# AI4M/math-select-less-llama8b
# mlfoundations-dev/nemo_nano_math_300k_eval_2e29
# ai2-adapt-dev/tulu_3_rewritten_100k-v2-ifeval-replaced-math
# mlfoundations-dev/a1_math_open2math_10k_eval_636d
# mlfoundations-dev/a1_math_open2math_3k_eval_636d
# mlfoundations-dev/a1_math_open2math_1k_eval_636d
# mlfoundations-dev/a1_math_open2math_0.3k_eval_636d
# presencesw/OpenR1-Math-220k_problem_solution_test
# TingchenFu/MathIF
# CohenQu/CoRA_math_reasoning_benchmark_scaling
# presencesw/OpenR1-Math-220k_problem_solution
# SMSHAH/open-math-reasoning
# anonymous21016/math_raw_trajectory_format_filtered
# linrany/math_light_batch_inference_v1
# LuyiCui/MATH-SFT
# hcju/mathlibretrieval
# CreitinGameplays/math-r1-sft-0306-mistral
# Gabriel34190/qcm-maths-childrens
# Epitech/qcm_math
# afraamn/olympiadbench_math_textonly
# mlfoundations-dev/no_pipeline_math_300k_eval_08c7
# mlfoundations-dev/no_pipeline_math_30k_eval_08c7
# mlfoundations-dev/no_pipeline_math_100k_eval_08c7
# mlfoundations-dev/no_pipeline_math_0.3k_eval_08c7
# mlfoundations-dev/no_pipeline_math_10k_eval_08c7
# mlfoundations-dev/no_pipeline_math_3k_eval_08c7
# mlfoundations-dev/no_pipeline_math_eval_08c7
# mlfoundations-dev/no_pipeline_math_1k_eval_08c7
# hamishivi/openr1_math_220k
# hamishivi/big_math_rl_verified
# hamishivi/numina_math_1_5
# hamishivi/meta_math_qa
# aliazn/mathchatsync-temp
# ayushchakravarthy/math-env
# ayushchakravarthy/math-en
# mlfoundations-dev/nemo_nano_math_300k_eval_08c7
# mlfoundations-dev/openthoughts2_math_0.3k_eval_08c7
# mlfoundations-dev/openthoughts2_math_1k_eval_08c7
# mlfoundations-dev/openthoughts2_math_10k_eval_08c7
# mlfoundations-dev/openthoughts2_math_3k_eval_08c7
# mlfoundations-dev/openthoughts2_math_100k_eval_08c7
# mlfoundations-dev/openthoughts2_math_30k_eval_08c7
# mlfoundations-dev/openthoughts2_math_300k_eval_08c7
# mlfoundations-dev/openthoughts_math_3k_eval_08c7
# mlfoundations-dev/openthoughts_math_10k_eval_08c7
# mlfoundations-dev/openthoughts_math_30k_eval_08c7
# mlfoundations-dev/openthoughts_math_1k_eval_08c7
# mlfoundations-dev/openthoughts_math_0.3k_eval_08c7
# mlfoundations-dev/openthoughts_math_eval_08c7
# yashmahe2018/math-error-classification-dataset
# 10pi/puple-math-dpo
# Nguyentruong031203/DAPO_Math_17k_Processed_vi
# mmmanuel/cleaned-math-preference-dpo
# lehduong/math-dolmino
# mehuldamani/orm-math1b-correctness-no-confidence
# gankun/G-Math-Diagram
# qe2/DAPO-Math-17k-Processed-ja
# NLPForUA/dumy-zno-ukrainian-math-history-geo-r1-o1
# lauriewz/hle_math
# lauriewz/jeebench_math
# chaitalibh/mathdatset
# RyanLucas3/OpenR1-Math-50
# mlfoundations-dev/e1_math_all_r1_0.3k
# mlfoundations-dev/e1_math_all_r1_1k
# mlfoundations-dev/e1_math_all_r1_3k
# mlfoundations-dev/e1_math_all_r1_10k
# enosislabs/math-mini-shareGPT
# Epitech/MathProblem
# dim/hendrycks_math_train_12k_DeepSeek-R1-Distill-Qwen-1.5B_max_len_4096_greedy
# jsm0424/math500-deepseek-r1-distill-qwen-1.5b
# jamesjje/DAPO-Math-17k_dedup_jje
# sunyiyou/math_arithmetic_matrix_rank_level_6
# sunyiyou/math_difficulty_level_5_problems
# jsm0424/math500-deepseek-r1-distill-qwen-14b
# xuanfeiren/math_hard_gemini
# linrany/math_light_batch_inference_v2
# YuchenLi01/MATH_train_generations-Qwen2.5-1.5B-Instruct
# YuchenLi01/MATH_Qwen2.5-1.5BInstruct_DPO_MoreUniqueResponseNoGT
# YuchenLi01/MATH_Qwen2.5-1.5BInstruct_DPO_MoreUniqueResponseIncludeGT
# hamishivi/rlvr_orz_math_57k_collected
# sunyiyou/math_arithmetic_matrix_multiplication_level_5
# sunyiyou/math_arithmetic_matrix_svd_level_6
# sunyiyou/math_arithmetic_matrix_eigenvalues_level_4
# sunyiyou/math_combinatory_probability_no_specific_letter_fixed_level_2
# sunyiyou/math_combinatory_probability_at_least_n_specific_fixed_level_2
# sunyiyou/math_arithmetic_matrix_eigenvalues_level_6
# sunyiyou/math_combinatory_distribution_level_5
# sunyiyou/math_arithmetic_mixed_level_2
# sunyiyou/math_arithmetic_matrix_svd_level_4
# sunyiyou/math_arithmetic_matrix_rank_level_4
# sunyiyou/math_arithmetic_matrix_multiplication_level_7
# sunyiyou/math_arithmetic_matrix_determinant_level_2
# sunyiyou/math_algebra_linear_equation_level_4
# sunyiyou/math_arithmetic_gcd_level_5
# sunyiyou/math_arithmetic_list_prime_factors_level_4
# sunyiyou/math_arithmetic_gcd_level_1
# sunyiyou/math_arithmetic_matrix_multiplication_level_3
# sunyiyou/math_arithmetic_matrix_determinant_level_6
# sunyiyou/math_combinatory_probability_at_least_n_specific_fixed_level_4
# sunyiyou/math_combinatory_probability_no_specific_letter_fixed_level_4
# sunyiyou/math_combinatory_distribution_level_1
# sunyiyou/math_arithmetic_matrix_eigenvalues_level_2
# sunyiyou/math_combinatory_distribution_level_3
# sunyiyou/math_algebra_linear_equation_level_2
# sunyiyou/math_arithmetic_list_prime_factors_level_2
# sunyiyou/math_arithmetic_gcd_level_3
# sunyiyou/math_arithmetic_matrix_rank_level_2
# sunyiyou/math_arithmetic_matrix_multiplication_level_1
# sunyiyou/math_arithmetic_matrix_determinant_level_4
# sunyiyou/math_arithmetic_mixed_level_4
# sunyiyou/math_arithmetic_matrix_svd_level_2
# sunyiyou/math_combinatory_distribution_level_4
# sunyiyou/math_arithmetic_matrix_eigenvalues_level_7
# sunyiyou/math_combinatory_probability_at_least_n_specific_fixed_level_1
# sunyiyou/math_combinatory_probability_no_specific_letter_fixed_level_1
# sunyiyou/math_algebra_linear_equation_level_5
# sunyiyou/math_arithmetic_gcd_level_4
# sunyiyou/math_arithmetic_list_prime_factors_level_5
# sunyiyou/math_arithmetic_matrix_rank_level_5
# sunyiyou/math_arithmetic_matrix_multiplication_level_6
# sunyiyou/math_arithmetic_matrix_determinant_level_3
# sunyiyou/math_arithmetic_mixed_level_3
# sunyiyou/math_arithmetic_matrix_svd_level_5
# sunyiyou/math_arithmetic_matrix_svd_level_7
# sunyiyou/math_arithmetic_mixed_level_1
# sunyiyou/math_arithmetic_matrix_rank_level_7
# sunyiyou/math_arithmetic_matrix_multiplication_level_4
# sunyiyou/math_arithmetic_matrix_determinant_level_1
# sunyiyou/math_combinatory_probability_at_least_n_specific_fixed_level_3
# sunyiyou/math_combinatory_probability_no_specific_letter_fixed_level_3
# sunyiyou/math_arithmetic_matrix_eigenvalues_level_5
# sunyiyou/math_arithmetic_matrix_eigenvalues_level_1
# sunyiyou/math_combinatory_distribution_level_2
# sunyiyou/math_arithmetic_mixed_level_5
# sunyiyou/math_arithmetic_matrix_svd_level_3
# sunyiyou/math_arithmetic_matrix_rank_level_3
# sunyiyou/math_arithmetic_matrix_determinant_level_5
# sunyiyou/math_algebra_linear_equation_level_3
# sunyiyou/math_arithmetic_list_prime_factors_level_3
# sunyiyou/math_arithmetic_gcd_level_2
# sunyiyou/math_arithmetic_matrix_rank_level_1
# sunyiyou/math_arithmetic_matrix_multiplication_level_2
# sunyiyou/math_arithmetic_matrix_determinant_level_7
# sunyiyou/math_arithmetic_list_prime_factors_level_1
# sunyiyou/math_algebra_linear_equation_level_1
# sunyiyou/math_arithmetic_matrix_svd_level_1
# sunyiyou/math_arithmetic_matrix_eigenvalues_level_3
# sunyiyou/math_combinatory_probability_no_specific_letter_fixed_level_5
# sunyiyou/math_combinatory_probability_at_least_n_specific_fixed_level_5
# sunyiyou/math_arithmetic_matrix_inverse_level_6
# sunyiyou/math_arithmetic_matrix_power_level_7
# sunyiyou/math_combinatory_pattern_matching_level_4
# sunyiyou/math_combinatory_probability_exactly_n_specific_fixed_level_2
# sunyiyou/math_combinatory_probability_no_fixed_points_level_2
# sunyiyou/math_arithmetic_matrix_power_level_5
# sunyiyou/math_arithmetic_matrix_inverse_level_4
# sunyiyou/math_combinatory_probability_exactly_n_specific_fixed_level_4
# sunyiyou/math_combinatory_pattern_matching_level_2
# sunyiyou/math_arithmetic_matrix_power_level_1
# sunyiyou/math_arithmetic_matrix_power_level_3
# sunyiyou/math_combinatory_probability_no_fixed_points_level_4
# sunyiyou/math_arithmetic_matrix_inverse_level_2
# sunyiyou/math_arithmetic_matrix_power_level_4
# sunyiyou/math_combinatory_probability_no_fixed_points_level_3
# sunyiyou/math_combinatory_probability_exactly_n_specific_fixed_level_1
# sunyiyou/math_arithmetic_matrix_inverse_level_5
# sunyiyou/math_arithmetic_matrix_inverse_level_7
# sunyiyou/math_combinatory_probability_exactly_n_specific_fixed_level_3
# sunyiyou/math_arithmetic_matrix_power_level_6
# sunyiyou/math_combinatory_pattern_matching_level_5
# sunyiyou/math_combinatory_probability_no_fixed_points_level_1
# sunyiyou/math_combinatory_probability_no_fixed_points_level_5
# sunyiyou/math_arithmetic_matrix_power_level_2
# sunyiyou/math_combinatory_pattern_matching_level_1
# sunyiyou/math_arithmetic_matrix_inverse_level_3
# sunyiyou/math_arithmetic_matrix_inverse_level_1
# sunyiyou/math_combinatory_pattern_matching_level_3
# sunyiyou/math_combinatory_probability_exactly_n_specific_fixed_level_5
# smoorsmith/gsm8k___txt___Qwen2.5-MATH-7B-Instruct
# Jax-dan/Reasoning-Math23K
# WalidBouss/MathVision_subset
# justus27/rl-math-filtered-difficult
# Yuanxin-Liu/mix-math-7b-emodel-round2-rs
# Jennny/math-conversations
# King-8/math_messaging
# zhangchenxu/HardVerify-Math
# linrany/math_limo_mix_v1
# linrany/math_limo_mix_v2
# linrany/math_limo_mix_v3
# Mathieu-Thomas-JOSSET/plan
# WalidBouss/MathVision_subset-RL
# aledm03/tulu-3-sft-personas-math-grade-filtered
# sunyiyou/math_algebra_func_derivative_sign_level_1
# sunyiyou/math_algebra_func_extrema_coords_level_1
# sunyiyou/math_algebra_func_intersection_level_1
# sunyiyou/math_algebra_func_extrema_coords_level_3
# sunyiyou/math_algebra_func_intersection_level_3
# sunyiyou/math_algebra_func_derivative_sign_level_3
# sunyiyou/math_algebra_func_intersection_level_5
# sunyiyou/math_algebra_func_extrema_coords_level_5
# sunyiyou/math_algebra_func_derivative_sign_level_5
# sunyiyou/math_algebra_func_intersection_level_2
# sunyiyou/math_algebra_func_extrema_coords_level_2
# sunyiyou/math_algebra_func_derivative_sign_level_2
# sunyiyou/math_algebra_func_extrema_coords_level_4
# sunyiyou/math_algebra_func_intersection_level_4
# sunyiyou/math_algebra_func_derivative_sign_level_4
# sunyiyou/math_algebra_func_extrema_level_4
# sunyiyou/math_algebra_func_zeros_level_2
# sunyiyou/math_algebra_func_area_level_4
# sunyiyou/math_algebra_func_intersection_coords_level_1
# sunyiyou/math_algebra_func_intersection_coords_level_3
# sunyiyou/math_algebra_func_extrema_level_2
# sunyiyou/math_algebra_func_area_level_2
# sunyiyou/math_algebra_func_zeros_level_4
# sunyiyou/math_algebra_func_intersection_coords_level_5
# sunyiyou/math_algebra_func_zeros_level_1
# sunyiyou/math_algebra_func_intersection_coords_level_2
# sunyiyou/math_algebra_func_extrema_level_5
# sunyiyou/math_algebra_func_area_level_5
# sunyiyou/math_algebra_func_zeros_level_3
# sunyiyou/math_algebra_func_area_level_1
# sunyiyou/math_algebra_func_intersection_coords_level_4
# sunyiyou/math_algebra_func_extrema_level_1
# sunyiyou/math_algebra_func_extrema_level_3
# sunyiyou/math_algebra_func_zeros_level_5
# sunyiyou/math_algebra_func_area_level_3
# YuchenLi01/MATH_Qwen2.5-1.5BInstruct_Soft_DPO_Qwen2.5MathPRM72B_MoreNoGT
# PirxTion/math_qa-test
# owl-agent/dpo_math_workforce
# kolerk/TON-Math-SFT
# sxLiu/math500_validation
# ReasoningTrap/MATH500
# Jiawei1222/MathEquiv
# jsm0424/math500-deepseek-r1
# dougiefresh/grammar_logic_rhetoric_and_math
# ikerm11/math
# ryo0634/math-short-thought
# ryo0634/math-thought
# ryo0634/math-thought-filtered
# ryo0634/math-short-thought-filtered
# anonym-submit-paper/Finetuning-Trajectories-Math
# Malikeh1375/complex_mathematical-scientific-notation-parallel
# Malikeh1375/basic_mathematical-scientific-notation-parallel
# sunyiyou/math_comp_grid_chips
# sunyiyou/math_comp_vertex_color
# sunyiyou/math_trans_gridworld
# sunyiyou/math_trans_circles
# sunyiyou/math_trans_integrations
# Blancy/secondfiltered-math220k-difficulty_stratified_10k_tokenknown
# DARELab/MathE
# autoprogrammer/amthinking_math_classified
# FlameF0X/Math-2
# Asap7772/d1shs0ap_math_split_verl_processed
# Blancy/secondfiltered-math220k-difficulty_stratified_10k_filtered_only_medium_difficulty
# mlfoundations-dev/e1_math_all_r1_0.3k_eval_5554
# jouyang/treecut-math
# mlfoundations-dev/e1_math_all_r1_1k_eval_5554
# mathieussr/arxiv-physics_DPO
# mathieussr/AI4Chem-ChemData700K_DPO
# mathieussr/OpenR1-Math-220k_DPO
# mathieussr/MetaMathQA_DPO
# mathieussr/ultrafeedback-binarized-preferences-cleaned_DPO
# mathieussr/ai-physics_DPO
# Slim205/mathlib
# mathieussr/orpo-dpo-mix-40k_DPO
# mathieussr/Kaggle-LLM-Science-Exam_DPO
# mathieussr/openlifescienceai_medmcqa_DPO
# mathieussr/medical-o1-reasoning-SFT_DPO
# mathieussr/pref-pair_DPO
# mathieussr/dataset_DPO
# mlfoundations-dev/openthoughts2_math_300k_eval_2e29
# jsm0424/math500-deepseek-r1-distill-qwen-1.5b-constrained
# ShuoZheLi/math-7500-ruiyang
# stalaei/real-math-dataset-633-with-dependencies
# stalaei/real-math-dataset-226-with-proof-dependencies
# stalaei/real-math-dataset-207-with-extra-proof-dependencies
# Manojkumarks/math-word-problems
# mlfoundations-dev/e1_math_all_r1_10k_eval_5554
# mlfoundations-dev/e1_math_all_r1_3k_eval_5554
# jsm0424/math500-deepseek-r1-distill-qwen-14b-constrained
# Malikeh1375/tokenizer-robustness-math-mmlu
# MYC081/math_3b_eval_correct
# jsm0424/math500-deepseek-r1-distill-qwen-1.5b-constrained2
# guanning/math
# PirxTion/math_qa-train
# PirxTion/math-step-dpo-10k
# PirxTion/preferece-data-math-stack-exchange
# jaeyong2/Math-code-Qwen3-06B-Ko
# winglian/OpenThoughts-114k-math-correct
# javifer/synthetic-math-hallucinations
# javifer/synthetic-math-hallucinations-v2
# MYC081/math_3b_eval_gpt_correct
# mathieussr/MNLP_M2_dpo_model
# Meiyi-Q03/MathClean
# pss0204/math500_token_data_real
# davgauch/MNLP_M2_mcqa_dataset_math_en_synth
# pss0204/math500_token
# arm-team/Stage2_RL_MATH
# smoorsmith/gsm8k___32t___Qwen2.5-MATH-7B-Instruct
# jaeyong2/Math-code-Qwen3-1.7B-Ko
# research2025/math40k
# PrimeIntellect/INTELLECT-2-only-math
# SeongeonKim/openai-grade-school-math
# ChaosAiVision/benmark_MATH-500
# riddickz/multitask_v3_math_5_5k
# riddickz/multitask_v3_math_11k
# Mahlia/MNLP_math_dpo_dataset
# ChuGyouk/DAPO-Math-14k-Processed-Fixed
# smoorsmith/gsm8k___2txt___Qwen2.5-MATH-7B-Instruct___Qwen2.5-Coder-7B-Instruct
# Mahlia/MNLP_math_dpo_formatted_dataset
# linrany/open_r1_math
# smoorsmith/gsm8k___4t___Qwen2.5-MATH-7B-Instruct
# smoorsmith/gsm8k___6t___Qwen2.5-MATH-7B-Instruct
# smoorsmith/gsm8k___16t___Qwen2.5-MATH-7B-Instruct
# rediska0123/test_math_Qwen3-1.7B
# mlfoundations-dev/openthoughts3_math_100k_eval_2e29
# Jennny/math-conversations2
# Jennny/math-conversations_mc
# Jennny/math-conversations_overall
# autoprogrammer/amthinking_math_lf_sampled
# LucidityAI/Qwen2.5-math-code-200k
# liumy2010/UFT-MATH_3_4_5
# sunyiyou/math_trans_prob_letter
# Yuanxin-Liu/mix-math-7b-emodel-round3-rs
# mathieuschanz/Wiki12kTextSegmentation
# aochongoliverli/Qwen2.5-Math-1.5B-deepmath-hard-1800-steps-4096-reasoning-data
# faezeb/tulu_3_rewritten_100k-no-math
# faezeb/general-thoughts-100k-rewritten-no-math
# faezeb/RLVR-IFeval-no-math
# faezeb/chemistry_qa-no-math
# faezeb/logic_701-no-math
# faezeb/logic_lm-no-math
# faezeb/virtuoussy_multi_subject_rlvr-no-math
# YuchenLi01/MATH_train_generations-Qwen2.5-1.5B-Instruct-reeval
# ebony59/MATH-lighteval-gen
# thdsofia/argilla-distilabel-math-preference-dpo
# justus27/filtered-rl-non-math-code
# rediska0123/train_math_Qwen3-1.7B
# YuchenLi01/MATH_Qwen2.5-1.5BInstruct_DPO_generatedAndParaphrasedMoreUniqueResponseNoGT
# mm-o1/mm-mathinstruct-gemini
# mehuldamani/orz-math-57k
# vinhpx/nvidia-math-dataset
# di-zhang-fdu/greatmix-math-stem
# yobro4619/dapo-math-filtered
# HINT-lab/DAPO-Math-17k-Filtered
# WaltonFuture/clevr-math
# HINT-lab/lime-difficulty-combined-qwen-math-7b
# Leo-Dai/dapo-math-17k_dedup
# hdong0/Qwen__Qwen2.5-Math-1.5B_num_erased_tokens_128_remove_think_prompt_1
# Cornell-AGI/math_size_qwen2.5_1.5b_eval
# Cornell-AGI/math_size_qwen2.5_3b_eval
# Cornell-AGI/math_size_qwen2.5_7b_eval
# aochongoliverli/Qwen2.5-Math-1.5B-deepmath-hard-1800-steps-4096-self-distill-sft
# Elliott/Openr1-Math-48k-Complement
# learningarena/Mathematics
# yobro4619/dapo-math-filtered-sample
# Jenjamin3000/RAG_documents_math
# RyanYr/brm-dapo-llama3.2-3B-it_lr1e-6_rspL4096-beta0.001_matheval

# %%
from datasets import load_dataset, Dataset, DatasetDict
import random, getpass

# ------------------------------------------------------------------
# 1. PARAMETERS – edit these three lines
# ------------------------------------------------------------------
TARGET_SIZE   = 10_000          # rows you want in the subset (int or None)
TARGET_SPLIT  = "train"         # "train", "test", or "all"
PUSH_TO_HUB   = False           # set True to upload under your username
# ------------------------------------------------------------------

# 2. LOAD (streaming avoids downloading all 50 GB of parquet shards)
ds = load_dataset("open-r1/OpenR1-Math-220k", split=TARGET_SPLIT,
                  streaming=True)    # returns an IterableDataset

# 3. SAMPLE the first N rows (you could also random-sample)
subset_iter = (row for _, row in zip(range(TARGET_SIZE), ds))
subset_list = list(subset_iter)
subset      = Dataset.from_list(subset_list)

print(subset)                     # sanity-check
example = subset[0]
# print(example["prompt"][0]["content"][:200])   # peek at a question

# # 4. (Optional) wrap back into DatasetDict so you keep split names
# subset_ddict = DatasetDict({TARGET_SPLIT: subset})

# # 5. SAVE locally
# subset.save_to_disk(f"OpenR1-Math-220k-{TARGET_SPLIT}-{TARGET_SIZE}")

# # 6. (Optional) upload to Hub
# if PUSH_TO_HUB:
#     repo_name = f"{getpass.getuser()}/OpenR1-Math-220k-{TARGET_SIZE}"
#     subset_ddict.push_to_hub(repo_name,
#                              private=False,
#                              token=getpass.getpass("HF_token: "))
#     print(f"Pushed to https://huggingface.co/datasets/{repo_name}")
# Out:
# Resolving data files:   0%|          | 0/20 [00:00<?, ?it/s]
# Dataset({
#     features: ['problem', 'solution', 'answer', 'problem_type', 'question_type', 'source', 'uuid', 'is_reasoning_complete', 'generations', 'correctness_math_verify', 'correctness_llama', 'finish_reasons', 'correctness_count', 'messages'],
#     num_rows: 10000
# })

# %%
from datasets import load_dataset, DatasetDict

SUBSET_SIZE = 10_000         # ← change to whatever you need

# 1) Stream the full repo (fast, no huge download)
ds_all = load_dataset("open-r1/OpenR1-Math-220k", split="train", streaming=True)

# 2) Materialise just N rows into RAM and arrow
subset_rows = [row for _, row in zip(range(SUBSET_SIZE), ds_all)]
train_subset = DatasetDict({"train": DatasetDict.from_list(subset_rows)["train"]})
# If the repo also has a 'test' split and you want it:
# test_subset  = load_dataset(..., split="test").select(range(1000))

# 3) Save locally
train_subset.save_to_disk("/shared/public/data/rlucas/OpenR1-Math-10k")
print("Wrote subset to OpenR1-Math-10k/")

# %%
from datasets import load_dataset, DatasetDict

SUBSET_SIZE = 10_000         # ← change to whatever you need

# 1) Stream the full repo (fast, no huge download)
ds_all = load_dataset("open-r1/OpenR1-Math-220k", split="train", streaming=True)

# 2) Materialise just N rows into RAM and arrow
subset_rows = [row for _, row in zip(range(SUBSET_SIZE), ds_all)]
train_subset = DatasetDict({"train": DatasetDict.from_list(subset_rows)["train"]})
# If the repo also has a 'test' split and you want it:
# test_subset  = load_dataset(..., split="test").select(range(1000))

# 3) Save locally
train_subset.save_to_disk("/shared/public/data/rlucas/OpenR1-Math-10k")
print("Wrote subset to OpenR1-Math-10k/")
